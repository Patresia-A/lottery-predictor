# %% [markdown]
# <a href="https://colab.research.google.com/github/Patresia-A/lottery-predictor/blob/main/predict_next_draws.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !git clone https://github.com/YOUR_USERNAME/lottery-predictor.git
# %cd lottery-predictor

# !pip install -r requirements.txt
